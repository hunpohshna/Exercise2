# %% [markdown]
# ## 1. Create a Histogram for iris dataset

# %%
import seaborn as sns

import matplotlib.pyplot as plt
iris = sns.load_dataset("iris")

#datasets = sns.get_dataset_names()
#print(datasets)
print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.histplot(data=iris, x="petal_length")
# add labels and title
sns.set_theme(style="whitegrid",palette='rocket')
plt.xlabel("Petal Length (cm)")

plt.ylabel("Frequency")
plt.savefig(fname='figure23',orientation='landscape')
plt.title("Distribution of Petal Lengths in Iris Flowers")
# display the plot
plt.show()
# Out:
# F:\Program-Files\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## 2. Create a Scatter Plot for tips dataset

# %%
import seaborn as sns
from matplotlib import pyplot as plt
# Load the Tips dataset
tips = sns.load_dataset("tips")
print(tips)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_theme(style="whitegrid")
sns.scatterplot(x="total_bill", y="tip", data=tips,hue='day',palette='deep')
# add labels and title
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.title("Relationship between Total Bill and Tip")
plt.show()

# %% [markdown]
# ## 3. Create a bar plot for titanic dataset

# %%
titanic = sns.load_dataset("titanic")
print(titanic.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(x="class", y="fare", palette='rocket', data=titanic,hue='sex')
plt.xlabel("Class")
plt.ylabel("Fare")
sns.set_theme(style="whitegrid")
plt.title("Average Fare by Class and Gender on the Titanic")
# display the plot
plt.figure(figsize=(8, 6))
plt.show()
# Out:
# F:\Program-Files\Anaconda\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# F:\Program-Files\Anaconda\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# ## 4. create a Heatmap for tip and flight dataset

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Load the dataset

tips = sns.load_dataset('tips')
# Create a heatmap of the correlation between variables
newdf=tips.iloc[:,[0,1,6]]
print(newdf)
corr = newdf.corr()
print(corr)
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
sns.heatmap(corr,cmap='viridis',cbar=True, annot=True)
# Show the plot

plt.show()

# %%
# Load the dataset

flights = sns.load_dataset('flights')
print(flights)
# Pivot the data

newdf = flights.pivot(index='month', columns='year',values= 'passengers')
print(newdf)
# Create a heatmap
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# ...

# %%
sns.heatmap(newdf, cmap='viridis', annot=True,cbar=True, fmt='d')

# Set the title and axis labels

plt.title('Passengers per month')

plt.xlabel('Year')

plt.ylabel('Month')

# Show the plot

plt.show()

# %% [markdown]
# ## 5. Create a Pairplot for Iris dataset

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Load iris dataset

iris = sns.load_dataset("iris")
print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Create pair plot with custom settings

sns.set_theme(style="whitegrid")
sns.pairplot(data=iris,hue = 'species',diag_kind = "kde",kind = "scatter",palette = "rocket")
# Set title
plt.title("Iris Dataset Pair Plot")
# Show plot
#plt.figure(figsize=(8, 6))
plt.savefig(fname='figurepairplot',orientation='landscape')
plt.show()
# Out:
# F:\Program-Files\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# F:\Program-Files\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# F:\Program-Files\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ## 6. create a count plot for tips and titanic dataset

# %%
 # Show value counts for two categorical variables and using hue parameter:

#While the points are plotted in two dimensions, another dimension can be added to the plot by coloring the points according to a third variable.
 
import seaborn as sns
import matplotlib.pyplot as plt

# read a tips.csv file from seaborn library
df = sns.load_dataset('tips')
sns.set_theme(style="whitegrid") 
# count plot on two categorical variable
sns.countplot(x ='sex', hue = "smoker", data = df)
 
# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       5 import seaborn as sns
#       6 import matplotlib.pyplot as plt
# ----> 7 print(df.head())
#       9 # read a tips.csv file from seaborn library
#      10 df = sns.load_dataset('tips')
#
# NameError: name 'df' is not defined

# %%
#The count plot can be thought of as a histogram across a categorical variable.The example below demonstrates the count plot
import matplotlib.pyplot as plt
import seaborn as sns
 
# load dataset
titanic = sns.load_dataset('titanic')
# create plot
print(titanic.head())
 
sns.set_theme(style="whitegrid")
sns.countplot(x = 'class', hue = 'who', data = titanic, palette = 'magma')
plt.title('Category of passenger')
plt.show()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# ...
